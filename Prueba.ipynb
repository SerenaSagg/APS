# %%
# Hola
print("Bloque 1")
x=10
# Out:
# Bloque 1

# %%
print("Bloque2")
print("X=",x)
# Out:
# Bloque2
# X= 10

# %% [markdown]
# # Hola
# ## Es una prueba
# ### subtitulo
# texto, texto, ...
#
# - primero
# - segundo
# - *cursiva*
# - **negrita**
#
#
#   ![imagen](https://filosofia.net/cdf/uhm/img/uns.png)
