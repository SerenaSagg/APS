# %% [markdown]
# <img src="./logo_UNSAM.png" align="right" width="150" />
#
# #### Análisis y Procesamiento de Señales
#
# # Trabajo Práctico Nº1
# #### Serena Saggion

# %% [markdown]
# # Introducción
# En este trabajo se aborda la generación y el análisis de diferentes tipos de señales mediante herramientas de procesamiento digital. Se analizan sus características tanto en el dominio temporal como frecuencial mediante la Transformada de Fourier. Además, se aplican conceptos como potencia, media, varianza y convolución para comprender el comportamiento de las señales y sistemas.

# %% [markdown]
# # Teoría
# ## Media, varianza y desviación estándar
#
# En el análisis de señales aleatorias, la media, la varianza y la desviación estándar son parámetros estadísticos que permiten caracterizar el comportamiento de una señal.
#
# La *media* representa el valor promedio de las muestras y permite determinar la componente continua (DC) de la señal. Para una secuencia de \(N\) muestras se calcula como:
#
# \begin{equation}
# \mu_x = \frac{1}{N} \sum_{n=0}^{N-1} x[n]
# \end{equation}
#
# Si la media es igual a cero, la señal no presenta componente continua.
#
# La *varianza* indica cuánto se dispersan las muestras respecto de su valor medio. Se calcula mediante:
#
# \begin{equation}
# \sigma_x^2 = \frac{1}{N} \sum_{n=0}^{N-1} (x[n] - \mu_x)^2
# \end{equation}
#
# Una varianza pequeña indica que los valores se encuentran próximos a la media, mientras que una varianza mayor representa una mayor dispersión.
#
# La *desviación estándar* es la raíz cuadrada de la varianza:
#
# \begin{equation}
# \sigma_x = \sqrt{\sigma_x^2}
# \end{equation}
#
# Este parámetro resulta especialmente útil para caracterizar y generar señales aleatorias. Por ejemplo, una distribución normal puede definirse a partir de su media y su desviación estándar.
#
# ## Amplificación y relación con la potencia
#
# La amplificación de una señal consiste en aumentar su amplitud mediante la multiplicación por un factor **k** constante. Este proceso no altera la frecuencia ni la forma de la señal, sino únicamente su amplitud. \begin{equation} x_2(t) = k\,x_1(t)\end{equation}
#
# La potencia de una señal está directamente relacionada con el cuadrado de su amplitud. Por lo tanto, al aumentar la amplitud, la potencia también se incrementa de manera proporcional al cuadrado de dicho aumento.
#
# En términos logarítmicos, utilizados frecuentemente en procesamiento de señales, la amplificación suele expresarse en decibeles (dB), lo que permite cuantificar de forma más conveniente las variaciones de amplitud y potencia. \begin{equation} G_{dB} = 20 \log_{10}\left(\frac{A_2}{A_1}\right)\end{equation}
#
#
# ## Ruido aleatorio
#
# El ruido es una señal aleatoria cuyos valores varían de manera impredecible. Puede caracterizarse mediante parámetros estadísticos como la media, la varianza y la desviación estándar.
#
# En este trabajo se utilizan dos tipos de ruido: normal (gaussiano) y uniforme. El ruido normal concentra la mayor parte de sus valores alrededor de la media, mientras que en el ruido uniforme todos los valores dentro de un determinado intervalo tienen la misma probabilidad de ocurrencia.
#
#
# ## Señal rectangular y armónicos
#
# Una señal rectangular periódica alterna entre dos niveles de amplitud y se caracteriza por presentar cambios bruscos entre dichos niveles.
#
# A diferencia de una señal sinusoidal, una señal rectangular no puede representarse mediante una única componente frecuencial. Según el análisis de Fourier, puede descomponerse como una suma de señales sinusoidales de distintas frecuencias.
#
# En una señal rectangular simétrica aparecen la frecuencia fundamental y sus armónicos impares:
#
# La existencia de estos armónicos se debe a que son necesarias componentes de mayor frecuencia para representar los cambios bruscos de la señal y aproximar su forma rectangular.
#
# ## Transformada de Fourier
#
# La Transformada de Fourier permite analizar una señal en el dominio de la frecuencia, identificando las diferentes componentes frecuenciales que la forman. En el caso de una señal discreta de \(N\) muestras se utiliza la Transformada Discreta de Fourier (DFT), definida como:
#
# \begin{equation}
# X[k] = \sum_{n=0}^{N-1} x[n] e^{-j 2\pi kn/N}
# \end{equation}
#
# donde x[n] representa las muestras de la señal en el dominio temporal y X[k] representa su contenido en frecuencia.
#
# La Transformada Rápida de Fourier (FFT) es un algoritmo eficiente utilizado para calcular la DFT. El módulo de la transformada,
#
# \begin{equation}
# |X[k]|
# \end{equation}
#
# permite observar la magnitud de las componentes frecuenciales presentes en la señal.
#
# La resolución frecuencial de la transformada depende de la frecuencia de muestreo fs y de la cantidad de muestras N, y está dada por:
#
# \begin{equation}
# \Delta f = \frac{f_s}{N}
# \end{equation}
#
# De esta manera, mediante el análisis del módulo de la FFT es posible identificar las frecuencias predominantes de señales periódicas y observar la distribución espectral de señales aleatorias.
#
# ## Convolución de señales
# La convolución es una operación fundamental en el análisis de señales y sistemas lineales e invariantes en el tiempo (LTI), que permite determinar la salida de un sistema a partir de una señal de entrada y su respuesta al impulso. En tiempo discreto, se define como:
# \begin{equation} y[n] = \sum_{k=-\infty}^{\infty} x[k] \, h[n - k]\end{equation}
#
# lo que implica una suma de productos entre la señal de entrada y versiones desplazadas de la respuesta al impulso. Esta operación describe cómo el sistema modifica la señal de entrada para producir la salida .
#
# Un caso particular importante es la convolución con una delta discreta δ[n]. La delta actúa como elemento identidad, es decir:
# \begin{equation} x[n] * \delta[n] = x[n]\end{equation}
#
# y, si está desplazada:
# \begin{equation} x[n] * \delta[n - n_0] = x[n - n_0]\end{equation}
#
# Esto significa que convolucionar con una delta simplemente reproduce la señal original (o una versión desplazada), lo que refleja que la delta representa un sistema ideal que no altera la señal.

# %% [markdown]
# # Procedimiento
#
# ## Ejercicio 1
# Sintesis de señales y aplicaciones de operaciones.

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal


def mi_sen(vmax, dc, ff, ph, nn, fs):
    Ts = 1/fs
    tt = np.arange(nn) * Ts
    xx = dc + vmax * np.sin(2*np.pi*ff*tt + ph)
    return tt, xx

def calcular_fft(x, fs):
    N = len(x)
    X = np.fft.fft(x)* 2/N
    df=fs/N
    ff=np.arange(N)*df
    modulo = np.abs(X)

    return ff, modulo

# Parámetros
Np = 10
fs = 20000
ff = fs/Np
N = 1000
T = 1/ff
tt_ruido = np.arange(N) / fs

# 1) Señal original de 2 kHz
tt1, x1 = mi_sen(vmax=1, dc=0, ff=ff, ph=0, nn=N, fs=fs)
P1=np.var(x1)
f1, X1 = calcular_fft(x1, fs)

# 2) Misma señal con potencia 2W y desfasada en pi/2
Pot=2
vmax=np.sqrt(Pot*2)
tt2, x2 = mi_sen(vmax=vmax, dc=0, ff=ff, ph=np.pi/2, nn=N, fs=fs)
P2=np.var(x2)
f2, X2 = calcular_fft(x2, fs)

# 3) Ruido aleatorio con distribucion normal
Var=0.1
nn1=np.random.normal(0,np.sqrt(Var),N)  # Ruido gaussiano de media 0 y varianza 0.1
f3, X3 = calcular_fft(nn1, fs)

# 4) Ruido aleatorio con distribucion uniforme
Var=0.1
#varianza=((b-a)**2)/12
#como dc=0, a=-c y b=c
c=np.sqrt(Var*3)
nn2=np.random.uniform(-c,c,N)  # Ruido de media 0 y varianza 0.1
f4, X4 = calcular_fft(nn2, fs)

# 5) Pulso rectangular
tt3 = np.arange(N) / fs

x3 = signal.square(2*np.pi*ff*tt3,duty=0.5)
f5, X5 = calcular_fft(x3, fs)

# %% [markdown]
# **1. Señal sinusoidal de 2 KHz.**

# %%
# Gráfico 1
plt.figure()
plt.plot(f1, X1)
plt.title("FFT - Señal senoidal")
plt.xlabel("Frecuencia [Hz]")
plt.ylabel("|X(f)|")
plt.grid()
plt.show()

# %% [markdown]
# **2. Señal senoidal amplificada con potencia 2W y desfasada en π/2.**

# %%
# Gráfico 2
plt.figure()
plt.plot(f2, X2)
plt.title("FFT - Señal senoidal de 2 W")
plt.xlabel("Frecuencia [Hz]")
plt.ylabel("|X(f)|")
plt.grid()
plt.show()

# %% [markdown]
# **3. Secuencia aleatoria de ruido normalmente distribuido con DC (valor medio) 0V y varianza 0.1 W.**

# %%
# Gráfico 3
plt.figure()
plt.plot(f3, X3)
plt.title("FFT - Ruido Normal")
plt.xlabel("Frecuencia [Hz]")
plt.ylabel("|X(f)|")
plt.grid()
plt.show()

# %% [markdown]
# **4. Secuencia aleatoria de ruido uniformemente distribuido con DC (valor medio) 0V y varianza 0.1 W.**

# %%
# Gráfico 4
plt.figure()
plt.plot(f4, X4)
plt.title("FFT - Ruido Uniforme")
plt.xlabel("Frecuencia [Hz]")
plt.ylabel("|X(f)|")
plt.grid()
plt.show()

# %% [markdown]
# **5. Un pulso rectangular de la misma frecuencia, 1 W de potencia y ciclo de actividad del 50%.**

# %%
# Gráfico 5
plt.figure()
plt.plot(f5, X5)
plt.title("FFT - Señal rectangular")
plt.xlabel("Frecuencia [Hz]")
plt.ylabel("|X(f)|")
plt.grid()
plt.show()

# %% [markdown]
# ## Ejercicio 2
# Dado  \begin{equation} h[n] = \delta[n] - \delta[n - 4]\end{equation}  , encontrar y[n] = x[n] * h[n] para cada una de las siguientes **x[n]**:
#
# a)  \begin{equation} x[n] = \cos(\omega_0 n T_s)\end{equation} Expresar la respuesta como un único coseno de la forma A cos(ω₀. n . TS + φ).
#
# b) \begin{equation} x[n] = \left( \frac{1}{2} \right)^n u[n]\end{equation}
#
# c)  \begin{equation} x[n] = u[n+1] - u[n-2]\end{equation}
# <div align="center">
#     <img src="./ejercicio_1a.jpg" width="70%"  />
#     <img src="./ejercicio_1b.jpg"  width="70%" />
#     <img src="./ejercicios_byc.jpg"  width="70%" />
# </div>

# %% [markdown]
# # Análisis de Resultados
# En primer lugar, en la Transformada de Fourier del *gráfico 1* se observa una componente dominante en la frecuencia de 2 kHz, coincidente con la frecuencia de la señal generada. Esto demuestra que una señal sinusoidal ideal está compuesta por una única componente frecuencial.
#
# En el *gráfico 2* se representa la misma señal sinusoidal, pero con una potencia media de 2 W y un desfasaje. El aumento de potencia se relaciona directamente con un aumento de la amplitud de la señal, lo cual puede verificarse al compararla con la señal original. En el espectro se mantiene la componente principal en 2 kHz, ya que tanto el cambio de amplitud como el desfasaje no modifican la frecuencia de la señal. La variacion de la fase no se observa,ya que se trata del modulo de la transferencia. Si analizaramos la fase de la transformada de Fourier seguramente observariamos algun cambio.
#
# En el *gráfico 3*, correspondiente al ruido con distribución normal, no se observa una única componente frecuencial dominante. Su espectro se encuentra distribuido a lo largo de un amplio rango de frecuencias y presenta un comportamiento irregular debido a la naturaleza aleatoria de la señal.
#
# En el *gráfico 4*, correspondiente al ruido con distribución uniforme, también se observan componentes distribuidas a lo largo del espectro, sin una frecuencia fundamental definida. Al igual que en el ruido normal, el módulo de la FFT presenta variaciones aleatorias entre las distintas frecuencias.
#
# Aunque el ruido normal y el uniforme poseen distribuciones estadísticas diferentes, ambos fueron generados con media cero y varianza 0.1, por lo que sus espectros pueden presentar un aspecto general similar.
#
# En el *gráfico 5* se observa que, a diferencia de una señal sinusoidal, una señal rectangular no está compuesta por una única componente frecuencial. Se distinguen picos importantes en 2 kHz y 6 kHz. El primero corresponde a la frecuencia fundamental de la señal y el segundo podemos pensar que corresponde a unis de los armónicos característicos de estas señales.
#
# En la segunda parte del trabajo se calculó la salida de diferentes sistemas mediante la convolución de las señales de entrada **x[n]** con una respuesta al impulso **h[n]** conformada por deltas desplazadas.

# %% [markdown]
# # Conclusión
# A lo largo del trabajo se logró sintetizar y analizar diferentes tipos de señales, tanto periódicas como aleatorias. Mediante la Transformada de Fourier fue posible observar sus principales características en el dominio de la frecuencia, identificando la frecuencia fundamental de las señales sinusoidales, la distribución espectral del ruido y la presencia de armónicos en la señal rectangular. De esta manera, se pudo comprobar la relación existente entre las características temporales de una señal y su representación en frecuencia.
#
# Asi mismo, se demostró la importancia de una correcta elección de la frecuencia de muestreo y la cantidad de muestras, respetando el criterio de Nyquist para evitar aliasing y garantizar una adecuada representación de las señales.
#
# Por otro lado, el uso de la convolución permitió comprender el comportamiento de los sistemas a partir de su respuesta al impulso.
